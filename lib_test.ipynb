# %%
import tensorflow as tf 
if tf.test.is_built_with_cuda():
    print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0
# 2023-05-05 15:44:22.464865: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-05 15:44:22.464961: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-05 15:44:22.465003: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-05 15:44:22.465290: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-05 15:44:22.465304: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1722] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-05-05 15:44:22.465349: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-05 15:44:22.465368: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:0 with 9509 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:0a:00.0, compute capability: 8.6

# %%
import torch
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# NVIDIA GeForce RTX 3060

# %%
import jax
print(jax.lib.xla_bridge.get_backend().platform)
# Out:
# gpu

# %%
import numpy as np
np.arange(6)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
import scipy.integrate as integrate
integrate.quad(lambda x: x**3, 0, 2.0)
# Out:
# (4.0, 4.440892098500626e-14)

# %%
import sympy
x = sympy.Symbol('x')
sympy.diff(sympy.sin(x), x)
# Out:
# cos(x)

# %%
import pandas as pd
pd.DataFrame({'A': [1, 2, 3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
import matplotlib.pyplot as plt 
plt.plot([0, 1, 2], [2, 3, 4])

# %%
from astropy import units as u
(20 * u.m) / (2 * u.s)
# Out:
# <Quantity 10. m / s>

# %%
import sunpy.map
from sunpy.data.sample import AIA_171_ROLL_IMAGE
aia_map = sunpy.map.Map(AIA_171_ROLL_IMAGE)
aia_map.peek()

# %%
import datetime
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.feature.nightshade import Nightshade


fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

date = datetime.datetime(1999, 12, 31, 12)

ax.set_title(f'Night time shading for {date}')
ax.stock_img()
ax.add_feature(Nightshade(date, alpha=0.2))
plt.show()

# %%
import pyvista as pv
pv.set_jupyter_backend('trame')
from pyvista import examples
mesh = examples.download_st_helens()
warped = mesh.warp_by_scalar('Elevation')
surf = warped.extract_surface().triangulate()
surf = surf.decimate_pro(0.75)  # reduce the density of the mesh by 75%
surf.plot(cmap='gist_earth')
# Out:
# Widget(value="<iframe src='http://localhost:36863/index.html?ui=P_0x7f12e46657b0_1&reconnect=auto' style='widt…
