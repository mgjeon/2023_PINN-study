# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "0"

# %%
os.environ["DDE_BACKEND"] = 'tensorflow'
import deepxde as dde
# Out:
# Using backend: tensorflow
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 os.environ["DDE_BACKEND"] = 'tensorflow'
# ----> 2 import deepxde as dde
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/__init__.py:17
#      14 from .__about__ import __version__
#      16 # Should import backend before importing anything else
# ---> 17 from . import backend
#      19 from . import callbacks
#      20 from . import data
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/backend/__init__.py:100
#      96     set_default_backend("tensorflow.compat.v1")
#      97     return "tensorflow.compat.v1"
# --> 100 load_backend(get_preferred_backend())
#     103 def is_enabled(api):
#     104     """Return true if the api is enabled by the current backend.
#     105
#     106     Args:
#    (...)
#     110         bool: ``True`` if the API is enabled by the current backend.
#     111     """
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/backend/__init__.py:36, in load_backend(mod_name)
#      33     raise NotImplementedError("Unsupported backend: %s" % mod_name)
#      35 print("Using backend: %s\n" % mod_name, file=sys.stderr, flush=True)
# ---> 36 mod = importlib.import_module(".%s" % mod_name.replace(".", "_"), __name__)
#      37 thismod = sys.modules[__name__]
#      38 # log backend name
#
# File ~/mambaforge/envs/dde/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/backend/tensorflow/__init__.py:5
#       1 import os
#       3 os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"
# ----> 5 from .tensor import *  # pylint: disable=redefined-builtin
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/backend/tensorflow/tensor.py:4
#       1 """tensorflow backend implementation"""
#       2 from packaging.version import Version
# ----> 4 import tensorflow as tf
#       5 import tensorflow_probability as tfp
#       8 if Version(tf.__version__) < Version("2.2.0"):
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import numpy as np

# %% [markdown]
# # Learning a function from a formula

# %%
def func(x):
    return x*np.sin(5*x)

# %%
geom = dde.geometry.Interval(-1, 1)
geom

# %%
num_train = 16
num_test = 100
data = dde.data.Function(geom, func, num_train, num_test)
data

# %%
activation = 'tanh'
initializer = 'Glorot uniform'
net = dde.nn.FNN([1] + [20]*3 + [1], activation, initializer)
net
# Out:
# FNN(
#   (linears): ModuleList(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): Linear(in_features=20, out_features=20, bias=True)
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
model = dde.Model(data, net)
model.compile('adam', lr=0.001, metrics=['l2 relative error'])
model
# Out:
# Compiling model...
# 'compile' took 0.000884 s

# %%
losshistory, train_state = model.train(iterations=10000)
# Out:
# Training model...
#
# 0         [3.01e-01]    [2.60e-01]    [1.12e+00]
# 1000      [2.67e-04]    [2.60e-04]    [3.53e-02]
# 2000      [4.21e-05]    [6.60e-05]    [1.78e-02]
# 3000      [3.67e-06]    [2.73e-05]    [1.14e-02]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 losshistory, train_state = model.train(iterations=10000)
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/utils/internal.py:22, in timing.<locals>.wrapper(*args, **kwargs)
#      19 @wraps(f)
#      20 def wrapper(*args, **kwargs):
#      21     ts = timeit.default_timer()
# ---> 22     result = f(*args, **kwargs)
#      23     te = timeit.default_timer()
#      24     print("%r took %f s\n" % (f.__name__, te - ts))
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/model.py:624, in Model.train(self, iterations, batch_size, display_every, disregard_previous_best, callbacks, model_restore_path, model_save_path, epochs)
#     622     if iterations is None:
#     623         raise ValueError("No iterations for {}.".format(self.opt_name))
# --> 624     self._train_sgd(iterations, display_every)
#     625 self.callbacks.on_train_end()
#     627 print("")
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/model.py:641, in Model._train_sgd(self, iterations, display_every)
#     636 self.callbacks.on_batch_begin()
#     638 self.train_state.set_data_train(
#     639     *self.data.train_next_batch(self.batch_size)
#     640 )
# --> 641 self._train_step(
#     642     self.train_state.X_train,
#     643     self.train_state.y_train,
#     644     self.train_state.train_aux_vars,
#     645 )
#     647 self.train_state.epoch += 1
#     648 self.train_state.step += 1
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/model.py:539, in Model._train_step(self, inputs, targets, auxiliary_vars)
#     536     self.train_step(inputs, targets, auxiliary_vars)
#     537 elif backend_name == "pytorch":
#     538     # TODO: auxiliary_vars
# --> 539     self.train_step(inputs, targets)
#     540 elif backend_name == "jax":
#     541     # TODO: auxiliary_vars
#     542     self.params, self.opt_state = self.train_step(
#     543         self.params, self.opt_state, inputs, targets
#     544     )
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/model.py:341, in Model._compile_pytorch.<locals>.train_step(inputs, targets)
#     338     total_loss.backward()
#     339     return total_loss
# --> 341 self.opt.step(closure)
#     342 if self.lr_scheduler is not None:
#     343     self.lr_scheduler.step()
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/torch/optim/optimizer.py:113, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     111 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112 with torch.autograd.profiler.record_function(profile_name):
# --> 113     return func(*args, **kwargs)
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/torch/optim/adam.py:118, in Adam.step(self, closure)
#     116 if closure is not None:
#     117     with torch.enable_grad():
# --> 118         loss = closure()
#     120 for group in self.param_groups:
#     121     params_with_grad = []
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/model.py:338, in Model._compile_pytorch.<locals>.train_step.<locals>.closure()
#     336 total_loss = torch.sum(losses)
#     337 self.opt.zero_grad()
# --> 338 total_loss.backward()
#     339 return total_loss
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/torch/_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
losshistory

# %%
train_state

# %%
dde.saveplot(losshistory, train_state, issave=False, isplot=True)

# %% [markdown]
# # Learning a function from a dataset

# %%
# !wget -N https://raw.githubusercontent.com/lululxvi/deepxde/master/examples/dataset/dataset.train
# !wget -N https://raw.githubusercontent.com/lululxvi/deepxde/master/examples/dataset/dataset.test
# Out:
# --2023-04-04 13:08:23--  https://raw.githubusercontent.com/lululxvi/deepxde/master/examples/dataset/dataset.train
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘dataset.train’ not modified on server. Omitting download.
#
# --2023-04-04 13:08:24--  https://raw.githubusercontent.com/lululxvi/deepxde/master/examples/dataset/dataset.test
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25824 (25K) [text/plain]
# Saving to: ‘dataset.test’
#
# dataset.test        100%[===================>]  25.22K  --.-KB/s    in 0.02s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-04-04 13:08:25 (1.03 MB/s) - ‘dataset.test’ saved [25824/25824]

# %%
fname_train = 'dataset.train'
fname_test = 'dataset.test'

# %%
data = dde.data.DataSet(
    fname_train=fname_train,
    fname_test=fname_test,
    col_x=(0,),
    col_y=(1,),
    standardize=True,
)

# %%
layer_size = [1] + [50]*3 + [1]
activation = 'tanh'
initializer = 'Glorot normal'
net = dde.nn.FNN(layer_size, activation, initializer)

# %%
model = dde.Model(data, net)
model.compile('adam', lr=0.001, metrics=['l2 relative error'])
losshistory, train_state = model.train(iterations=50000)
# Out:
# Compiling model...
# 'compile' took 0.000575 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 0         [3.92e-01]    [4.09e-01]    [8.96e-01]
# 1000      [7.20e-03]    [7.32e-03]    [1.20e-01]
# 2000      [5.64e-03]    [6.02e-03]    [1.09e-01]
# 3000      [5.13e-03]    [5.62e-03]    [1.05e-01]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 3
#       1 model = dde.Model(data, net)
#       2 model.compile('adam', lr=0.001, metrics=['l2 relative error'])
# ----> 3 losshistory, train_state = model.train(iterations=50000)
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/utils/internal.py:22, in timing.<locals>.wrapper(*args, **kwargs)
#      19 @wraps(f)
#      20 def wrapper(*args, **kwargs):
#      21     ts = timeit.default_timer()
# ---> 22     result = f(*args, **kwargs)
#      23     te = timeit.default_timer()
#      24     print("%r took %f s\n" % (f.__name__, te - ts))
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/model.py:624, in Model.train(self, iterations, batch_size, display_every, disregard_previous_best, callbacks, model_restore_path, model_save_path, epochs)
#     622     if iterations is None:
#     623         raise ValueError("No iterations for {}.".format(self.opt_name))
# --> 624     self._train_sgd(iterations, display_every)
#     625 self.callbacks.on_train_end()
#     627 print("")
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/model.py:641, in Model._train_sgd(self, iterations, display_every)
#     636 self.callbacks.on_batch_begin()
#     638 self.train_state.set_data_train(
#     639     *self.data.train_next_batch(self.batch_size)
#     640 )
# --> 641 self._train_step(
#     642     self.train_state.X_train,
#     643     self.train_state.y_train,
#     644     self.train_state.train_aux_vars,
#     645 )
#     647 self.train_state.epoch += 1
#     648 self.train_state.step += 1
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/model.py:539, in Model._train_step(self, inputs, targets, auxiliary_vars)
#     536     self.train_step(inputs, targets, auxiliary_vars)
#     537 elif backend_name == "pytorch":
#     538     # TODO: auxiliary_vars
# --> 539     self.train_step(inputs, targets)
#     540 elif backend_name == "jax":
#     541     # TODO: auxiliary_vars
#     542     self.params, self.opt_state = self.train_step(
#     543         self.params, self.opt_state, inputs, targets
#     544     )
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/model.py:341, in Model._compile_pytorch.<locals>.train_step(inputs, targets)
#     338     total_loss.backward()
#     339     return total_loss
# --> 341 self.opt.step(closure)
#     342 if self.lr_scheduler is not None:
#     343     self.lr_scheduler.step()
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/torch/optim/optimizer.py:113, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     111 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112 with torch.autograd.profiler.record_function(profile_name):
# --> 113     return func(*args, **kwargs)
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/torch/optim/adam.py:118, in Adam.step(self, closure)
#     116 if closure is not None:
#     117     with torch.enable_grad():
# --> 118         loss = closure()
#     120 for group in self.param_groups:
#     121     params_with_grad = []
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/deepxde/model.py:338, in Model._compile_pytorch.<locals>.train_step.<locals>.closure()
#     336 total_loss = torch.sum(losses)
#     337 self.opt.zero_grad()
# --> 338 total_loss.backward()
#     339 return total_loss
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/torch/_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/mambaforge/envs/dde/lib/python3.9/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
